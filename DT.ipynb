# %%
from sklearn.datasets import load_iris

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
iris = load_iris()

# %%
X=iris.data

# %%
y=iris.target

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test=  train_test_split(X,y, test_size=0.25)

# %%
X_train.shape
# Out:
# (112, 4)

# %%
y_train.shape
# Out:
# (112,)

# %%
X_test.shape
# Out:
# (38, 4)

# %%
y_test.shape
# Out:
# (38,)

# %%
from sklearn.metrics import accuracy_score

# %%
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
accuracy_score(y_pred,y_test)
# Out:
# 0.9210526315789473

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={
    
    'max_depth':[2,3,4,5,6],
    'min_samples_split':[2,3,4,5],
    'min_samples_leaf':[2,3,4]
}

# %%
grid_search = GridSearchCV(model,param_grid=param_grid,cv=5)

# %%
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [2, 3, 4, 5, 6],
#                          'min_samples_leaf': [2, 3, 4],
#                          'min_samples_split': [2, 3, 4, 5]})

# %%
grid_search.best_params_
# Out:
# {'max_depth': 2, 'min_samples_leaf': 2, 'min_samples_split': 2}

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=2, min_samples_leaf=2)

# %%
model2=DecisionTreeClassifier(max_depth=3,min_samples_leaf= 2, min_samples_split= 2)
model2.fit(X_train,y_train)
y_pred2 = model2.predict(X_test)
accuracy_score(y_pred2,y_test)
# Out:
# 0.9210526315789473

# %%
train=100%
validation=92.11%

# %%
100-92.11
# Out:
# 7.890000000000001

# %%
domain expert/ data scientist

training and testing accuray diff should not be more than 5%

in that case you will reject this 

you will say here

it is overfitting

# %%
model2.score(X_train,y_train)
# Out:
# 0.9732142857142857

# %%
round(0.9821428571428571,2)
# Out:
# 0.98

# %%
training accuracy=98%
validation accuracy=97%

# %%
# this is my general model 

# there is no overfittig and underfitting

# it is permoing well on my train and tst data both

# genral or best fit model
98-97

# %%
# here you will select this model why?

# %%
# training and testing accuray diff should not be more than 5%

# %%
import matplotlib.pyplot as plt

# %%
from sklearn import tree

# %%
plt.figure(figsize=(25,20))
tree.plot_tree(model,filled=True)
# Out:
# [Text(0.3181818181818182, 0.9166666666666666, 'x[2] <= 2.6\ngini = 0.665\nsamples = 112\nvalue = [34, 40, 38]'),
#  Text(0.22727272727272727, 0.75, 'gini = 0.0\nsamples = 34\nvalue = [34, 0, 0]'),
#  Text(0.4090909090909091, 0.75, 'x[3] <= 1.65\ngini = 0.5\nsamples = 78\nvalue = [0, 40, 38]'),
#  Text(0.18181818181818182, 0.5833333333333334, 'x[0] <= 7.1\ngini = 0.05\nsamples = 39\nvalue = [0, 38, 1]'),
#  Text(0.09090909090909091, 0.4166666666666667, 'gini = 0.0\nsamples = 38\nvalue = [0, 38, 0]'),
#  Text(0.2727272727272727, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6363636363636364, 0.5833333333333334, 'x[3] <= 1.75\ngini = 0.097\nsamples = 39\nvalue = [0, 2, 37]'),
#  Text(0.45454545454545453, 0.4166666666666667, 'x[1] <= 2.75\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.36363636363636365, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.5454545454545454, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
# ...

# %%
plt.figure(figsize=(25,20))
tree.plot_tree(model2,filled=True)
# Out:
# [Text(0.375, 0.875, 'x[3] <= 0.8\ngini = 0.665\nsamples = 112\nvalue = [34, 40, 38]'),
#  Text(0.25, 0.625, 'gini = 0.0\nsamples = 34\nvalue = [34, 0, 0]'),
#  Text(0.5, 0.625, 'x[3] <= 1.65\ngini = 0.5\nsamples = 78\nvalue = [0, 40, 38]'),
#  Text(0.25, 0.375, 'x[0] <= 6.95\ngini = 0.05\nsamples = 39\nvalue = [0, 38, 1]'),
#  Text(0.125, 0.125, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0]'),
#  Text(0.375, 0.125, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.75, 0.375, 'x[3] <= 1.75\ngini = 0.097\nsamples = 39\nvalue = [0, 2, 37]'),
#  Text(0.625, 0.125, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.875, 0.125, 'gini = 0.053\nsamples = 37\nvalue = [0, 1, 36]')]

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3} 
print(my_dict.get('d', 4))
# Out:
# 4
